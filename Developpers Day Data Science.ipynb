# %% [markdown]
# # Exploratory Data Analysis for Developers Day
#
# This is a simple EDA of the NYPD public dataset from 2003.

# %%
import pandas as pd

# %% [markdown]
# Open dataset

# %%
df = pd.read_csv('./data/nypd.data/2008.csv',low_memory=False)
df.dtypes
df
# Out:
#         year  pct  ser_num  datestop timestop recstat inout trhsloc  perobs  \
# 0       2008   42     1044   1012008     0130       A     O            20.0
# 1       2008  108        3   1012008     2010       A     I             1.0
# 2       2008  100       15   1082008     0100       A     O       H     2.0
# 3       2008  103      210   1082008     1905       A     O             2.0
# 4       2008   71       90   1122008     2125       A     I       H     5.0
# 5       2008   25     1392   1132008     2230       A     I       H     1.0
# 6       2008    6       69   1152008     1815       A     O             1.0
# 7       2008   23     1028   1172008     2035       1     O            10.0
# 8       2008   30      191   1172008     2140       A     I       T     1.0
# 9       2008   88      241   1242008     2055       A     I       H     1.0
# 10      2008   23     2695   1252008     0535       1     I       H     1.0
# 11      2008   73     1347   1252008     2225       A     I       H     5.0
# 12      2008   25     3057   1262008     1935       A     I       H     1.0
# 13      2008   25      686   1262008     2100       A     O             3.0
# 14      2008   25     3059   1292008     0940       A     I       H     5.0
# 15      2008   23     1810   2012008     2315       1     O             5.0
# 16      2008   10      269   2062008     1600       A     I       T     2.0
# 17      2008   23     2140   2082008     0220       1     I       H     1.0
# 18      2008   32     1611   2092008     0030       A     O             1.0
# 19      2008   26      655   2122008     1324       A     I       T     4.0
# 20      2008  108      870   2152008     0215       A     O             1.0
# 21      2008    9     1596   2162008     0334       1     I             1.0
# 22      2008   26      569   2172008     1606       A     I       T     5.0
# 23      2008   90     1146   2222008     1115       A     I             1.0
# 24      2008   32     2214   2222008     2015       A     O             1.0
# 25      2008   33      770   2292008     2100       A     O             5.0
# 26      2008  103     3272   3102008     1500       1     O             1.0
# 27      2008   79    11654   3212008     0245       A     O             3.0
# 28      2008   67     1423   3252008     1058       A     I            10.0
# 29      2008   30     2287   3262008     1412       A     O             2.0
# ...      ...  ...      ...       ...      ...     ...   ...     ...     ...
# 540272  2008   52     7724  12312008     2327       A     O             1.0
# 540273  2008   49     4533  12312008     2329       A     I       H     1.0
# 540274  2008   44     8956  12312008     2330       A     O             1.0
# 540275  2008   77     8243  12312008     2330       A     O             1.0
# 540276  2008   77     8244  12312008     2330       A     O             1.0
# 540277  2008  115     9725  12312008     2330       A     O             1.0
# 540278  2008   40    12442  12312008     2330       1     I       H     1.0
# 540279  2008    1     2498  12312008     2330       A     O            10.0
# 540280  2008   73    21842  12312008     2335       1     I       H     1.0
# 540281  2008   88     6244  12312008     2335       A     O             1.0
# 540282  2008   88     6242  12312008     2335       A     O             1.0
# 540283  2008   88     6241  12312008     2335       A     O             1.0
# 540284  2008   88     6243  12312008     2335       A     O             1.0
# 540285  2008   13     5199  12312008     2340       1     O             3.0
# 540286  2008   75    27125  12312008     2340       A     O             1.0
# 540287  2008   49     4572  12312008     2340       A     O             1.0
# 540288  2008   75    27124  12312008     2340       A     O             1.0
# 540289  2008   81     9710  12312008     2340       A     O             2.0
# 540290  2008   67     6835  12312008     2345       A     O             3.0
# 540291  2008   73    21844  12312008     2345       1     I       H     2.0
# 540292  2008   81     9677  12312008     2345       A     O             3.0
# 540293  2008   23    15388  12312008     2345       A     I       H     1.0
# 540294  2008  120    17332  12312008     2345       A     O             5.0
# 540295  2008   73    21845  12312008     2346       1     I       H     2.0
# 540296  2008   49     4532  12312008     2350       A     O       H     1.0
# 540297  2008  120    17399  12312008     2350       A     I       H     2.0
# 540298  2008   72     3740  12312008     2350       1     O             1.0
# 540299  2008   49     4587  12312008     2350       A     O            10.0
# 540300  2008  106     6437  12312008     2358       1     O             1.0
# 540301  2008  106     6445  12312008     2423       1     O             3.0
#
#                              crimsusp    ...     zip addrpct sector beat post  \
# 0                                 FEL    ...              42      B
# 1                            BURGLARY    ...             108      B
# 2                             ROBBERY    ...             100      B    2
# 3                             ROBBERY    ...             103      J   16
# 4                           CRIM-TRES    ...              71      C    5   PP
# 5                           CRIM TRES    ...              25      E
# 6                           MISD/CSCS    ...               6      A
# 7                                CSCS    ...              23      E        22
# 8                       PETIT LARCENY    ...              30      F
# 9                          CRIM TRESS    ...              88      G
# 10                          CRIM TRES    ...              23      H
# 11                          CRIM TRES    ...              73      I    9
# 12                  CRIMINAL TRESPASS    ...              25      C
# 13                          ROBBERY 2    ...              25      B        15
# 14                  CRIMINAL TRESPASS    ...              25      E
# 15                               CPCS    ...              23      E
# 16             ASSAULT 2/GANG ASSAULT    ...              10      A
# 17                      CRIMINAL TRES    ...              23      H
# 18                                FEL    ...              32      M   11   27
# 19                               MISD    ...              26      A
# 20                                GLA    ...             108
# 21                          CRIM TRES    ...               9      A    2
# 22                      GRAND LARCENY    ...              26      A
# 23                           BURGLARY    ...              90      G
# 24                                FEL    ...              32      M   11   80
# 25                            ROBBERY    ...              33
# 26                            ROBBERY    ...             103      B    3    9
# 27                               CPCS    ...              79      J   13
# 28                               MISD    ...              67      A
# 29                       FEL/BURGLARY    ...              30      E        29
# ...                               ...    ...     ...     ...    ...  ...  ...
# 540272                            CPW    ...              52      D
# 540273              CRIMINAL TRESPASS    ...              49      E    9
# 540274                         FELONY    ...              44      P
# 540275                         FELONY    ...              77      J    4
# 540276                         FELONY    ...              77      M    2
# 540277                            GLA    ...             115      A
# 540278           CRIMINAL TRESPASSING    ...              40      I    9
# 540279                  GRAND LARCENY    ...               1      I
# 540280                      CRIM TRES    ...              73      K   11
# 540281                            CPW    ...              88      G
# 540282                            CPW    ...              88      G
# 540283                           CSCS    ...              88      G
# 540284                           CSCS    ...              88      G
# 540285                   GL/CARBREAKS    ...              13      D
# 540286                         FELONY    ...              75      F
# 540287  CRIMINAL POSSESSION OF WEAPON    ...              49      H   13
# 540288                         FELONY    ...              75      F
# 540289                            CPW    ...              81      E    5
# 540290                            FEL    ...              67      M
# 540291                      CRIM TRES    ...              73      H    8
# 540292                            FEL    ...              81
# 540293                           MISD    ...              23      C
# 540294                           MISD    ...             120      T
# 540295                      CRIM TRES    ...              73      H    8
# 540296  CRIMINAL POSSESSION OF WEAPON    ...              49      I   15
# 540297                            CPM    ...             120      C
# 540298                           MISD    ...              72      D    1
# 540299                        ROBBERY    ...              49      H   13   18
# 540300                            FEL    ...             106      F
# 540301                            FEL    ...             106      H
#
#          xcoord   ycoord dettypcm  linecm  detailcm
# 0       1009873  0243953       CM       1        20
# 1       1001546  0210784       CM       1        14
# 2       1042944  0154180       CM       1        85
# 3       1050245  0196802       CM       1        85
# 4       0995112  0180043       CM       1        31
# 5       1001775  0234816       CM       1        31
# 6       0983859  0205623       CM       1        28
# 7       0999626  0228816       CM       1        28
# 8       1000476  0241999       CM       1        68
# 9       0991415  0193572       CM       1        31
# 10      0999670  0229445       CM       1        31
# 11      1009977  0182507       CM       1        31
# 12      0999292  0231183       CM       1        31
# 13      1000898  0231790       CM       1        85
# 14      1001823  0234903       CM       1        31
# 15      0999833  0228147       CM       1        24
# 16      0984338  0208351       CM       1         9
# 17      1001163  0229089       CM       1        31
# 18      1001495  0239626       CM       1        20
# 19      0997374  0234664       CM       1        68
# 20                             CM       1        46
# 21      0990768  0202439       CM       1        31
# 22      0997374  0234664       CM       1        45
# 23      1000348  0194921       CM       1        14
# 24      1001129  0238936       CM       1        20
# 25      1007190  0253954       CM       1        85
# 26      1040784  0197047       CM       1        85
# 27      0996412  0192333       CM       1        24
# 28      0997861  0177586       CM       1       112
# 29      0998104  0241594       CM       1        14
# ...         ...      ...      ...     ...       ...
# 540272  1013192  0253694       CM       1        20
# 540273  1022278  0252495       CM       1        31
# 540274  1007374  0244940       CM       1        20
# 540275  1004127  0182891       CM       1        20
# 540276  1004127  0182891       CM       1        20
# 540277  1019253  0215026       CM       1        46
# 540278  1005133  0235287       CM       1        31
# 540279  0982777  0204727       CM       1        45
# 540280  1009710  0180716       CM       1        31
# 540281                         CM       1        20
# 540282                         CM       1        20
# 540283                         CM       1        28
# 540284                         CM       1        28
# 540285  0989678  0209822       CM       1        45
# 540286  1014827  0180952       CM       1        20
# 540287  1020439  0255033       CM       1        20
# 540288  1014827  0180952       CM       1        20
# 540289  1005247  0190951       CM       1        20
# 540290  1006961  0178564       CM       1        20
# 540291  1009854  0184434       CM       1        31
# 540292                         CM       1        85
# 540293  0998148  0227834       CM       1        20
# 540294  0939363  0169442       CM       1        20
# 540295  1009854  0184434       CM       1        31
# 540296  1025423  0256066       CM       1        20
# 540297  0961386  0165788       CM       1        27
# 540298                         CM       1        20
# 540299  1020830  0254599       CM       1        85
# 540300  1030242  0186652       CM       1        46
# 540301  1038229  0185152       CM       1        85
#
# [540302 rows x 111 columns]

# %%
df.timestop = pd.to_datetime(df.timestop,format="%H%M",errors='ignore')
df.head(20)
# Out:
#     year  pct  ser_num  datestop timestop recstat inout trhsloc  perobs  \
# 0   2008   42     1044   1012008     0130       A     O            20.0
# 1   2008  108        3   1012008     2010       A     I             1.0
# 2   2008  100       15   1082008     0100       A     O       H     2.0
# 3   2008  103      210   1082008     1905       A     O             2.0
# 4   2008   71       90   1122008     2125       A     I       H     5.0
# 5   2008   25     1392   1132008     2230       A     I       H     1.0
# 6   2008    6       69   1152008     1815       A     O             1.0
# 7   2008   23     1028   1172008     2035       1     O            10.0
# 8   2008   30      191   1172008     2140       A     I       T     1.0
# 9   2008   88      241   1242008     2055       A     I       H     1.0
# 10  2008   23     2695   1252008     0535       1     I       H     1.0
# 11  2008   73     1347   1252008     2225       A     I       H     5.0
# 12  2008   25     3057   1262008     1935       A     I       H     1.0
# 13  2008   25      686   1262008     2100       A     O             3.0
# 14  2008   25     3059   1292008     0940       A     I       H     5.0
# 15  2008   23     1810   2012008     2315       1     O             5.0
# 16  2008   10      269   2062008     1600       A     I       T     2.0
# 17  2008   23     2140   2082008     0220       1     I       H     1.0
# 18  2008   32     1611   2092008     0030       A     O             1.0
# 19  2008   26      655   2122008     1324       A     I       T     4.0
#
#                   crimsusp    ...     zip addrpct sector beat post   xcoord  \
# 0                      FEL    ...              42      B            1009873
# 1                 BURGLARY    ...             108      B            1001546
# 2                  ROBBERY    ...             100      B    2       1042944
# 3                  ROBBERY    ...             103      J   16       1050245
# 4                CRIM-TRES    ...              71      C    5   PP  0995112
# 5                CRIM TRES    ...              25      E            1001775
# 6                MISD/CSCS    ...               6      A            0983859
# 7                     CSCS    ...              23      E        22  0999626
# 8            PETIT LARCENY    ...              30      F            1000476
# 9               CRIM TRESS    ...              88      G            0991415
# 10               CRIM TRES    ...              23      H            0999670
# 11               CRIM TRES    ...              73      I    9       1009977
# 12       CRIMINAL TRESPASS    ...              25      C            0999292
# 13               ROBBERY 2    ...              25      B        15  1000898
# 14       CRIMINAL TRESPASS    ...              25      E            1001823
# 15                    CPCS    ...              23      E            0999833
# 16  ASSAULT 2/GANG ASSAULT    ...              10      A            0984338
# 17           CRIMINAL TRES    ...              23      H            1001163
# 18                     FEL    ...              32      M   11   27  1001495
# 19                    MISD    ...              26      A            0997374
#
#      ycoord dettypcm  linecm  detailcm
# 0   0243953       CM       1        20
# 1   0210784       CM       1        14
# 2   0154180       CM       1        85
# 3   0196802       CM       1        85
# 4   0180043       CM       1        31
# 5   0234816       CM       1        31
# 6   0205623       CM       1        28
# 7   0228816       CM       1        28
# 8   0241999       CM       1        68
# 9   0193572       CM       1        31
# 10  0229445       CM       1        31
# 11  0182507       CM       1        31
# 12  0231183       CM       1        31
# 13  0231790       CM       1        85
# 14  0234903       CM       1        31
# 15  0228147       CM       1        24
# 16  0208351       CM       1         9
# 17  0229089       CM       1        31
# 18  0239626       CM       1        20
# 19  0234664       CM       1        68
#
# [20 rows x 111 columns]

# %% [markdown]
# ### The crimes that happend the most

# %%
top_crimes = df.groupby('crimsusp')['year'].count()
top_crimes.sort_values(ascending=False)
# Out:
# crimsusp
# CPW                               81300
# ROBBERY                           48805
# FEL                               45634
# FELONY                            39494
# MISD                              35174
# GLA                               34279
# BURGLARY                          29535
# CRIM TRES                         17634
# CRIMINAL TRESPASS                 13579
# CPCS                              12621
# BURG                              12463
# GRAND LARCENY                     11770
# ASSAULT                           10696
# CSCS                              10437
# CPM                                9158
# PETIT LARCENY                      6243
# MIS                                5014
# CRIM TRESS                         4941
# ROB                                3556
# CT                                 3288
# ROBB                               3046
# MISDEMEANOR                        2688
# CPSP                               2525
# CRIMINAL MISCHIEF                  2472
# MIS/CPW                            2252
# CRIM TRESPASS                      2189
# GRAND LARCENY AUTO                 2177
# GRAFFITI                           1793
# FELONY/ROBBERY                     1769
# C.P.W.                             1756
#                                   ...
# FIREWORKS  MISD  PSA #1548            1
# FELONYY                               1
# FERLONY                               1
# FELOON                                1
# FELOONY/CPW                           1
# FELOPNY                               1
# FELOWY                                1
# FELOY-CPW                             1
# FELR                                  1
# FEO                                   1
# FEOLNY                                1
# FEONY/ASSAULT                         1
# FEOONY                                1
# FEP                                   1
# FER                                   1
# FEWLONY                               1
# FIREWORKD                             1
# FFELONY/ BURGLARY                     1
# FGELONY/GRAND LARCENY                 1
# FGELONY/ROBBERY                       1
# FIGHTING                              1
# FILING FALSE POLICE REPORT            1
# FIREARM (GUNRUN)                      1
# FIREARM / DRUG SALES                  1
# FIREARM/ CPW                          1
# FIREARM/CSCS 1                        1
# FIREWORK                              1
# FIREWORK POSSESSION / C.P.C.S.        1
# FIREWORK SALE- MISD                   1
#    MISD                               1
# Name: year, dtype: int64

# %% [markdown]
# ## Create some visual
#
# * Top crimes
# * Sex of infractors

# %%
from bokeh.charts import Bar, Histogram
from bokeh.io import output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="60b5b703-6ed0-41b8-86aa-815292df60ba">Loading BokehJS ...</span>
#     </div>

# %%
p2 = Histogram(df, values='age')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4fa743261477> in <module>()
# ----> 1 p2 = Histogram(df, values='age')
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\builders\histogram_builder.pyc in Histogram(data, values, label, color, agg, bins, yscale, xgrid, ygrid, continuous_range, **kw)
#     104     kw['bins'] = bins
#     105
# --> 106     return create_and_build(HistogramBuilder, data, **kw)
#     107
#     108
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\builder.pyc in create_and_build(builder_class, *data, **kws)
#      71     chart_kws = {k: v for k, v in kws.items() if k not in builder_props}
#      72     chart = Chart(**chart_kws)
# ---> 73     chart.add_builder(builder)
#      74     chart.start_plot()
#      75
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\chart.pyc in add_builder(self, builder)
#     169     def add_builder(self, builder):
#     170         self._builders.append(builder)
# --> 171         builder.create(self)
#     172
#     173     def add_ranges(self, dim, range):
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\builder.pyc in create(self, chart)
#     535         if chart is None:
#     536             chart = Chart()
# --> 537         chart.add_renderers(self, renderers)
#     538
#     539         # handle ranges after renders, since ranges depend on aggregations
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\chart.pyc in add_renderers(self, builder, renderers)
#     164
#     165     def add_renderers(self, builder, renderers):
# --> 166         self.renderers += renderers
#     167         self._renderer_map.extend({ r._id : builder for r in renderers })
#     168
#
# C:\Anaconda2\lib\site-packages\bokeh\core\property_containers.pyc in wrapper(*args, **kwargs)
#      16         self = args[0]
#      17         old = self._saved_copy()
# ---> 18         result = func(*args, **kwargs)
#      19         self._notify_owners(old)
#      20         return result
#
# C:\Anaconda2\lib\site-packages\bokeh\core\property_containers.pyc in __iadd__(self, y)
#      75     @notify_owner
#      76     def __iadd__(self, y):
# ---> 77         return super(PropertyValueList, self).__iadd__(y)
#      78
#      79     # x *= y
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\builders\bar_builder.pyc in yield_renderers(self)
#     218                             stack_label=self._get_label(group['stack']),
#     219                             dodge_label=self._get_label(group['group']),
# --> 220                             **group_kwargs)
#     221
#     222             self.add_glyph(group, bg)
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\glyphs.pyc in __init__(self, values, label, color, bins, **kwargs)
#     947         self._bins = bins
#     948
# --> 949         super(HistogramGlyph, self).__init__(**kwargs)
#     950         self.setup()
#     951
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\glyphs.pyc in __init__(self, x_label, **kwargs)
#     487             kwargs['x_label'] = str(label)
#     488
# --> 489         super(AggregateGlyph, self).__init__(**kwargs)
#     490
#     491     def get_dodge_label(self, shift=0.0):
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\models.pyc in __init__(self, **properties)
#      79             properties['values'] = [vals]
#      80         super(CompositeGlyph, self).__init__(**properties)
# ---> 81         self.setup()
#      82
#      83     def setup(self):
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\models.pyc in setup(self)
#      83     def setup(self):
#      84         """Build renderers and data source and set sources on renderers."""
# ---> 85         self.renderers = [renderer for renderer in self.build_renderers()]
#      86         if self.renderers is not None:
#      87             self.refresh()
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\glyphs.pyc in build_renderers(self)
#     963         #               users specify other bins other the Histogram Stat
#     964         self.bins = Histogram(values=self.values, bins=self._bins,
# --> 965             density=self.density)
#     966
#     967         bars = []
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\stats.pyc in __init__(self, values, column, bins, stat, source, **properties)
#     309         properties['source'] = source
#     310         self._bins = bins
# --> 311         super(BinnedStat, self).__init__(**properties)
#     312
#     313
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\stats.pyc in __init__(self, **properties)
#      54
#      55         super(Stat, self).__init__(**properties)
# ---> 56         self._refresh()
#      57
#      58     def _refresh(self):
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\stats.pyc in _refresh(self)
#      59         """Lazy update of properties, used for initial transform init."""
#      60         if self.get_data() is not None:
# ---> 61             self.update()
#      62             self.calculate()
#      63
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\stats.pyc in update(self)
#     327
#     328     def update(self):
# --> 329         self.bin_stat = self._get_stat()
#     330         self.bin_stat.update()
#     331
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\stats.pyc in _get_stat(self)
#     324         stat_kwargs['bins'] = self._bins
#     325
# --> 326         return BinStats(**stat_kwargs)
#     327
#     328     def update(self):
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\stats.pyc in __init__(self, values, column, **properties)
#     239         properties['column'] = column or 'values'
#     240
# --> 241         super(BinStats, self).__init__(**properties)
#     242
#     243     def update(self):
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\stats.pyc in __init__(self, **properties)
#      54
#      55         super(Stat, self).__init__(**properties)
# ---> 56         self._refresh()
#      57
#      58     def _refresh(self):
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\stats.pyc in _refresh(self)
#      59         """Lazy update of properties, used for initial transform init."""
#      60         if self.get_data() is not None:
# ---> 61             self.update()
#      62             self.calculate()
#      63
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\stats.pyc in update(self)
#     243     def update(self):
#     244         values = self.get_data()
# --> 245         self.q1.set_data(values)
#     246         self.q3.set_data(values)
#     247         if self.bins is None:
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\stats.pyc in set_data(self, data, column)
#      75
#      76         self.update()
# ---> 77         self.calculate()
#      78
#      79     def get_data(self, column=None):
#
# C:\Anaconda2\lib\site-packages\bokeh\charts\stats.pyc in calculate(self)
#     152
#     153     def calculate(self):
# --> 154         self.value = self.get_data().quantile(self.interval)
#     155
#     156
#
# C:\Anaconda2\lib\site-packages\pandas\core\series.pyc in quantile(self, q, interpolation)
#    1359             kwargs.update({'interpolation': interpolation})
#    1360
# -> 1361         result = self._data.quantile(qs=q, **kwargs)
#    1362
#    1363         if com.is_list_like(result):
#
# C:\Anaconda2\lib\site-packages\pandas\core\internals.pyc in quantile(self, **kwargs)
#    2912
#    2913     def quantile(self, **kwargs):
# -> 2914         return self.apply('quantile', raw=True, **kwargs)
#    2915
#    2916     def setitem(self, **kwargs):
#
# C:\Anaconda2\lib\site-packages\pandas\core\internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, raw, **kwargs)
#    2888
#    2889             kwargs['mgr'] = self
# -> 2890             applied = getattr(b, f)(**kwargs)
#    2891             result_blocks = _extend_blocks(applied, result_blocks)
#    2892
#
# C:\Anaconda2\lib\site-packages\pandas\core\internals.pyc in quantile(self, qs, mgr, **kwargs)
#    1284             result = np.array(values)
#    1285         else:
# -> 1286             result = _quantile(values, qs * 100, **kwargs)
#    1287
#    1288         return self._try_coerce_result(result)
#
# C:\Anaconda2\lib\site-packages\numpy\lib\function_base.pyc in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3697     r, k = _ureduce(a, func=_percentile, q=q, axis=axis, out=out,
#    3698                     overwrite_input=overwrite_input,
# -> 3699                     interpolation=interpolation)
#    3700     if keepdims:
#    3701         if q.ndim == 0:
#
# C:\Anaconda2\lib\site-packages\numpy\lib\function_base.pyc in _ureduce(a, func, **kwargs)
#    3423         keepdim = [1] * a.ndim
#    3424
# -> 3425     r = func(a, **kwargs)
#    3426     return r, keepdim
#    3427
#
# C:\Anaconda2\lib\site-packages\numpy\lib\function_base.pyc in _percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3814             n = np.isnan(ap[-1:, ...])
#    3815
# -> 3816         x1 = take(ap, indices_below, axis=axis) * weights_below
#    3817         x2 = take(ap, indices_above, axis=axis) * weights_above
#    3818
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
show(p2)

# %%
min(df.year)
# Out:
# 2003

# %% [markdown]
# # Image recognition for digits
#
# A model is build to recognize hand written digits using the dataset provided by `scikit-learn`.

# %%
from sklearn.datasets import load_digits
# %matplotlib inline 
digits = load_digits()
digits.images.shape
# Out:
# (1797L, 8L, 8L)

# %% [markdown]
# The dataset contains 1797 images of `8x8` pixels.
#
# The figure below shows the first 100 digits.

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(10,10, figsize=(10,10),
                        subplot_kw= {'xticks':[],'yticks':[]},
                        gridspec_kw=dict(hspace=0.1,wspace=0.1))

for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i],cmap='binary',interpolation='nearest')
    ax.text(0.05,0.05, str(digits.target[i]),
           transform=ax.transAxes, color='green')

# %% [markdown]
# To train the model the data set must be separated between features (input `X` ) and labels (outputs `y`). We can represent each image as a 64 elements vector, thus definig 64 features.

# %%
X = digits.data
X.shape
# Out:
# (1797L, 64L)

# %%
y = digits.target
y.shape
# Out:
# (1797L,)

# %% [markdown]
# In order to visualize the dataset, each image is going to transform to a 2-dimensional space using a manifold algorithm called `Isomap`. We can see the results of this unspervised method for classifications in the image below.

# %%
from sklearn.manifold import Isomap

# %%
iso = Isomap(n_components=2)
iso.fit(digits.data)
data_projected = iso.transform(digits.data)
data_projected.shape
# Out:
# (1797L, 2L)

# %%
print "64 bytes array = %s"%X[0]
print "2D representation =%s"%data_projected[0]
# Out:
# 64 bytes array = [  0.   0.   5.  13.   9.   1.   0.   0.   0.   0.  13.  15.  10.  15.   5.
#    0.   0.   3.  15.   2.   0.  11.   8.   0.   0.   4.  12.   0.   0.   8.
#    8.   0.   0.   5.   8.   0.   0.   9.   8.   0.   0.   4.  11.   0.   1.
#   12.   7.   0.   0.   2.  14.   5.  10.  12.   0.   0.   0.   0.   6.  13.
#   10.   0.   0.   0.]
# 2D representation =[-167.27247954   22.18515653]

# %%
plt.scatter(data_projected[:,0],data_projected[:,1], c=digits.target,
           edgecolor = 'none', alpha = 0.5,
           cmap=plt.cm.get_cmap('spectral',10))
plt.colorbar(label='digit label', ticks=range(10))
plt.clim(-0.5,9.5)

# %% [markdown]
# This representation shows that the digits grouped in well defined clusters, some of the clusters present an overlap, this is clear between the `ones` in purple and the `senvens` in orange.

# %% [markdown]
# ## Classification on digits
#
# The previous representation shows that the digits are fairly well separated un the parameter space: this tell us that even a very straightforward supervised classification algorithm should perform sutirably on this data.

# %%
from sklearn.model_selectio
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-139cc3505715> in <module>()
# ----> 1 from sklearn.model_selection import train_test_split
#
# ImportError: No module named model_selection

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X,y,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-b4da84a01c4e> in <module>()
# ----> 1 Xtrain, Xtest, ytrain, ytest = train_test_split(X,y,random_state=0)
#
# NameError: name 'train_test_split' is not defined
